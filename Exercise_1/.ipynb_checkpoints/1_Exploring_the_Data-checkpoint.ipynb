# %%
from sklearn.datasets import load_digits

digits = load_digits()
print(digits.keys())

data = digits["data"]
images = digits["images"]
target = digits["target"]
target_names = digits["target_names"]
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
data.shape
# Out:
# (1797, 64)

# %% [markdown]
# ### Size of the images
# Each image consists of 8 x 8 digits, as shown for the first image in images.

# %%
image_example = images[0]
image_shape = images[0].shape

print(f"Example image: \n{image_example}")
print(f"\nShape of a single image: {image_shape}")
# Out:
# Example image:
# [[ 0.  0.  5. 13.  9.  1.  0.  0.]
#  [ 0.  0. 13. 15. 10. 15.  5.  0.]
#  [ 0.  3. 15.  2.  0. 11.  8.  0.]
#  [ 0.  4. 12.  0.  0.  8.  8.  0.]
#  [ 0.  5.  8.  0.  0.  9.  8.  0.]
#  [ 0.  4. 11.  0.  1. 12.  7.  0.]
#  [ 0.  2. 14.  5. 10. 12.  0.  0.]
#  [ 0.  0.  6. 13. 10.  0.  0.  0.]]
#
# Shape of a single image: (8, 8)

# %% [markdown]
# ## Visualize image of 3

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a 3 image
img = images[13]

assert 2 == len(img.shape)

# Display the image with nearest interpolation
plt.figure()
plt.gray()
plt.imshow(img, interpolation="nearest")
plt.title("Nearest interpolation")
plt.show()

# Display the image with bicubic interpolation
plt.figure()
plt.gray()
plt.imshow(img, interpolation="bicubic")
plt.title("Bicubic interpolation")
plt.show()

# %% [markdown]
# ## Filter 3 and 9 as well as generate Training and Test set

# %%
# Filter the digits 3 and 9
data_3_9 = [digits["data"][i] for i in range(len(digits["target"])) if digits["target"][i] in [3, 9]]
targets_3_9 = [digits["target"][i] for i in range(len(digits["target"])) if digits["target"][i] in [3, 9]]

# %%
print(targets_3_9[:5])
# Out:
# [3, 9, 3, 9, 3]

# %%
from sklearn import model_selection

X_all = data_3_9 
y_all = targets_3_9
X_train , X_test , y_train , y_test = model_selection.train_test_split(data_3_9, targets_3_9, test_size = 0.4, random_state = 0)

# %%
# Check if split was successful
print(len(X_all), len(y_all), len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 363 363 217 146 217 146
